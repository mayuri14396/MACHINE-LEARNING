# %%
import numpy as np
import pandas as pd

# %%
url = "https://www.news18.com/cricketnext/ipl-auction-2023/"
data = pd.read_html(url)
print(data)
# Out:
# [    #          Player | Squad  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0   1       Sam Curran | PBKS    20000000   ALL-ROUNDER            18.50
# 1   2      Cameron Green | MI    20000000   ALL-ROUNDER            17.50
# 2   3        Ben Stokes | CSK    20000000   ALL-ROUNDER            16.25
# 3   4   Nicholas Pooran | LSG    20000000  WICKETKEEPER            16.00
# 4   5       Harry Brook | SRH    15000000       BATSMAN            13.25
# 5   6    Mayank Agarwal | SRH    10000000       BATSMAN             8.25
# 6   7        Shivam Mavi | GT     4000000        BOWLER             6.00
# 7   8       Jason Holder | RR    20000000   ALL-ROUNDER             5.75
# 8   9       Mukesh Kumar | DC     2000000        BOWLER             5.50
# 9  10  Heinrich Klaasen | SRH    10000000  WICKETKEEPER             5.25
#
#    Cost IN $ (000) 2022 Squad
# 0             2220        NaN
# 1             2100        NaN
# 2             1950        NaN
# 3             1920        SRH
# ...

# %%
data[1]
# Out:
#           2023 Squad GT Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Shivam Mavi    4000000        BOWLER              6.0
# 1         Joshua Little    5000000        BOWLER              4.4
# 2       Kane Williamson   20000000       BATSMAN              2.0
# 3           K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4          Mohit Sharma    5000000        BOWLER              0.5
# 5           Odean Smith    5000000   ALL-ROUNDER              0.5
# 6           Urvil Patel    2000000  WICKETKEEPER              0.2
# 7         Rahul Tewatia   Retained   ALL-ROUNDER              0.0
# 8       Pradeep Sangwan   Retained   ALL-ROUNDER              0.0
# 9           Rashid Khan   Retained        BOWLER              0.0
# 10       R. Sai Kishore   Retained        BOWLER              0.0
# 11           Yash Dayal   Retained        BOWLER              0.0
# 12           Noor Ahmad   Retained        BOWLER              0.0
# ...

# %%
gujarat_titans = data[1]
gujarat_titans["Team"] = "Gujarat Titans"
gujarat_titans.rename(columns={"2023 Squad GT":"Player's List"},inplace = True)
gujarat_titans
# Out:
#           Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Shivam Mavi    4000000        BOWLER              6.0
# 1         Joshua Little    5000000        BOWLER              4.4
# 2       Kane Williamson   20000000       BATSMAN              2.0
# 3           K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4          Mohit Sharma    5000000        BOWLER              0.5
# 5           Odean Smith    5000000   ALL-ROUNDER              0.5
# 6           Urvil Patel    2000000  WICKETKEEPER              0.2
# 7         Rahul Tewatia   Retained   ALL-ROUNDER              0.0
# 8       Pradeep Sangwan   Retained   ALL-ROUNDER              0.0
# 9           Rashid Khan   Retained        BOWLER              0.0
# 10       R. Sai Kishore   Retained        BOWLER              0.0
# 11           Yash Dayal   Retained        BOWLER              0.0
# 12           Noor Ahmad   Retained        BOWLER              0.0
# ...

# %%
data[2]
# Out:
#             2023 Squad CSK Base Price          TYPE  COST IN ₹ (CR.)  \
# 0               Ben Stokes   20000000   ALL-ROUNDER            16.25
# 1            Kyle Jamieson   10000000        BOWLER             1.00
# 2           Nishant Sindhu    2000000   ALL-ROUNDER             0.60
# 3           Ajinkya Rahane    5000000       BATSMAN             0.50
# 4            Bhagath Varma    2000000   ALL-ROUNDER             0.20
# 5              Ajay Mandal    2000000   ALL-ROUNDER             0.20
# 6            Shaik Rasheed    2000000       BATSMAN             0.20
# 7          Ravindra Jadeja   Retained   ALL-ROUNDER             0.00
# 8   Rajvardhan Hangargekar   Retained   ALL-ROUNDER             0.00
# 9         Prashant Solanki   Retained        BOWLER             0.00
# 10         Ruturaj Gaikwad   Retained       BATSMAN             0.00
# 11        Tushar Deshpande   Retained        BOWLER             0.00
# 12        Mukesh Choudhary   Retained        BOWLER             0.00
# ...

# %%
csk=data[2]
csk["Team"]="Chennai Super Kings"
csk.rename(columns={"2023 Squad CSK":"Player's List"},inplace = True)

final=gujarat_titans.append(csk,ignore_index=True)
final
# Out:
# <ipython-input-6-0cf074ab52da>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=gujarat_titans.append(csk,ignore_index=True)
#              Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0              Shivam Mavi    4000000        BOWLER             6.00
# 1            Joshua Little    5000000        BOWLER             4.40
# 2          Kane Williamson   20000000       BATSMAN             2.00
# 3              K.S. Bharat    2000000  WICKETKEEPER             1.20
# 4             Mohit Sharma    5000000        BOWLER             0.50
# 5              Odean Smith    5000000   ALL-ROUNDER             0.50
# 6              Urvil Patel    2000000  WICKETKEEPER             0.20
# 7            Rahul Tewatia   Retained   ALL-ROUNDER             0.00
# 8          Pradeep Sangwan   Retained   ALL-ROUNDER             0.00
# ...

# %%
data[3]
# Out:
#          2023 Squad DC Base Price          TYPE  COST IN ₹ (CR.)  \
# 0         Mukesh Kumar    2000000        BOWLER              5.5
# 1        Rilee Rossouw   20000000       BATSMAN              4.6
# 2        Manish Pandey   10000000       BATSMAN              2.4
# 3            Phil Salt   20000000  WICKETKEEPER              2.0
# 4        Ishant Sharma    5000000        BOWLER              0.5
# 5          Ripal Patel   Retained   ALL-ROUNDER              0.0
# 6         Pravin Dubey   Retained   ALL-ROUNDER              0.0
# 7         Rishabh Pant   Retained  WICKETKEEPER              0.0
# 8         Prithvi Shaw   Retained       BATSMAN              0.0
# 9   Syed Khaleel Ahmed   Retained        BOWLER              0.0
# 10          Yash Dhull   Retained   ALL-ROUNDER              0.0
# 11        Vicky Ostwal   Retained   ALL-ROUNDER              0.0
# 12   Mustafizur Rahman   Retained        BOWLER              0.0
# ...

# %%
DC = data[3]
DC["Team"] = "Delhi Capitals"
DC.rename(columns={"2023 Squad DC":"Player's List"},inplace = True)
final_teams = final.append(DC,ignore_index = True)
final_teams
# Out:
# <ipython-input-8-a9f6f6fe5f52>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final.append(DC,ignore_index = True)
#         Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0         Shivam Mavi    4000000        BOWLER              6.0
# 1       Joshua Little    5000000        BOWLER              4.4
# 2     Kane Williamson   20000000       BATSMAN              2.0
# 3         K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4        Mohit Sharma    5000000        BOWLER              0.5
# ..                ...        ...           ...              ...
# 70       David Warner   Retained       BATSMAN              0.0
# 71    Lungisani Ngidi   Retained        BOWLER              0.0
# 72      Kuldeep Yadav   Retained        BOWLER              0.0
# 73  Kamlesh Nagarkoti   Retained   ALL-ROUNDER              0.0
# ...

# %%
data[4]
# Out:
#             2023 Squad KKR Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Shakib Al Hasan    1500000   ALL-ROUNDER              1.5
# 1              David Wiese   10000000   ALL-ROUNDER              1.0
# 2            N. Jagadeesan    2000000  WICKETKEEPER              0.9
# 3            Vaibhav Arora    2000000        BOWLER              0.6
# 4               Litton Das    5000000  WICKETKEEPER              0.5
# 5            Mandeep Singh    5000000       BATSMAN              0.5
# 6       Kulwant Khejroliya    2000000        BOWLER              0.2
# 7            Suyash Sharma    2000000        BOWLER              0.2
# 8             Sunil Narine   Retained        BOWLER              0.0
# 9             Shreyas Iyer   Retained       BATSMAN              0.0
# 10             Tim Southee   Retained        BOWLER              0.0
# 11             Umesh Yadav   Retained        BOWLER              0.0
# 12     Varun Chakaravarthy   Retained        BOWLER              0.0
# ...

# %%
KKR = data[4]
KKR["Team"] = "Kolkata Knight Riders"
KKR.rename(columns={"2023 Squad KKR":"Player's List"},inplace = True)
final_teams = final_teams.append(KKR,ignore_index = True)
final_teams
# Out:
# <ipython-input-10-8376693093c4>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(KKR,ignore_index = True)
#              Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0              Shivam Mavi    4000000        BOWLER              6.0
# 1            Joshua Little    5000000        BOWLER              4.4
# 2          Kane Williamson   20000000       BATSMAN              2.0
# 3              K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4             Mohit Sharma    5000000        BOWLER              0.5
# ..                     ...        ...           ...              ...
# 92           Andre Russell   Retained   ALL-ROUNDER              0.0
# 93     Lockie Ferguson (T)   Retained        BOWLER              0.0
# 94             Nitish Rana   Retained   ALL-ROUNDER              0.0
# ...

# %%
data[5]
# Out:
#         2023 Squad PBKS Base Price          TYPE  COST IN ₹ (CR.)  \
# 0            Sam Curran   20000000   ALL-ROUNDER             18.5
# 1         Sikandar Raza    5000000   ALL-ROUNDER              0.5
# 2       Harpreet Bhatia    2000000       BATSMAN              0.4
# 3          Mohit Rathee    2000000   ALL-ROUNDER              0.2
# 4     Vidwath Kaverappa    2000000        BOWLER              0.2
# 5          Shivam Singh    5000000  WICKETKEEPER              0.2
# 6      Liam Livingstone   Retained   ALL-ROUNDER              0.0
# 7   Baltej Singh Dhanda   Retained        BOWLER              0.0
# 8         Atharva Taide   Retained   ALL-ROUNDER              0.0
# 9     Bhanuka Rajapakse   Retained       BATSMAN              0.0
# 10        Jitesh Sharma   Retained  WICKETKEEPER              0.0
# 11         Nathan Ellis   Retained        BOWLER              0.0
# 12       Jonny Bairstow   Retained  WICKETKEEPER              0.0
# ...

# %%
PBKS = data[5]
PBKS["Team"] = "Punjab Super Kings"
PBKS.rename(columns={"2023 Squad PBKS":"Player's List"},inplace = True)
final_teams = final_teams.append(PBKS,ignore_index = True)
final_teams
# Out:
# <ipython-input-12-70171d198060>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(PBKS,ignore_index = True)
#          Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Shivam Mavi    4000000        BOWLER              6.0
# 1        Joshua Little    5000000        BOWLER              4.4
# 2      Kane Williamson   20000000       BATSMAN              2.0
# 3          K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4         Mohit Sharma    5000000        BOWLER              0.5
# ..                 ...        ...           ...              ...
# 114       Rahul Chahar   Retained        BOWLER              0.0
# 115     Arshdeep Singh   Retained        BOWLER              0.0
# 116  Prabhsimran Singh   Retained  WICKETKEEPER              0.0
# 117     Raj Angad Bawa   Retained   ALL-ROUNDER              0.0
# ...

# %%
data[6]
# Out:
#       2023 Squad LSG Base Price          TYPE  COST IN ₹ (CR.)  \
# 0    Nicholas Pooran   20000000  WICKETKEEPER            16.00
# 1        Daniel Sams    7500000   ALL-ROUNDER             0.75
# 2     Jaydev Unadkat    5000000        BOWLER             0.50
# 3      Naveen Ul Haq    5000000        BOWLER             0.50
# 4        Amit Mishra    5000000        BOWLER             0.50
# 5   Romario Shepherd    5000000   ALL-ROUNDER             0.50
# 6        Yash Thakur    2000000        BOWLER             0.45
# 7      Swapnil Singh    2000000   ALL-ROUNDER             0.20
# 8     Yudhvir Charak    2000000   ALL-ROUNDER             0.20
# 9      Prerak Mankad    2000000   ALL-ROUNDER             0.20
# 10         Mark Wood   Retained        BOWLER             0.00
# 11    Marcus Stoinis   Retained   ALL-ROUNDER             0.00
# 12      Mayank Yadav   Retained        BOWLER             0.00
# 13       Mohsin Khan   Retained        BOWLER             0.00
# ...

# %%
LSG = data[6]
LSG["Team"] = "Lucknow Super Giants"
LSG.rename(columns={"2023 Squad LSG":"Player's List"},inplace = True)
final_teams = final_teams.append(LSG,ignore_index = True)
final_teams
# Out:
# <ipython-input-14-8fd4fa22afac>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(LSG,ignore_index = True)
#        Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0        Shivam Mavi    4000000        BOWLER              6.0
# 1      Joshua Little    5000000        BOWLER              4.4
# 2    Kane Williamson   20000000       BATSMAN              2.0
# 3        K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4       Mohit Sharma    5000000        BOWLER              0.5
# ..               ...        ...           ...              ...
# 139       K. Gowtham   Retained   ALL-ROUNDER              0.0
# 140     Karan Sharma   Retained   ALL-ROUNDER              0.0
# 141    Krunal Pandya   Retained   ALL-ROUNDER              0.0
# 142         KL Rahul   Retained       BATSMAN              0.0
# ...

# %%
data[7]
# Out:
#             2023 Squad MI Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Cameron Green   20000000   ALL-ROUNDER             17.5
# 1         Jhye Richardson    1500000        BOWLER              1.5
# 2           Piyush Chawla    5000000        BOWLER              0.5
# 3            Raghav Goyal    2000000        BOWLER              0.2
# 4            Shams Mulani    2000000   ALL-ROUNDER              0.2
# 5           Nehal Wadhera    2000000   ALL-ROUNDER              0.2
# 6            Vishnu Vinod    2000000  WICKETKEEPER              0.2
# 7             Duan Jansen    2000000   ALL-ROUNDER              0.2
# 8         Ramandeep Singh   Retained   ALL-ROUNDER              0.0
# 9          N. Tilak Varma   Retained   ALL-ROUNDER              0.0
# 10      Mohd. Arshad Khan   Retained   ALL-ROUNDER              0.0
# 11           Rohit Sharma   Retained       BATSMAN              0.0
# 12       Suryakumar Yadav   Retained       BATSMAN              0.0
# ...

# %%
MI = data[7]
MI["Team"] = "Mumbai Indians"
MI.rename(columns={"2023 Squad MI":"Player's List"},inplace = True)
final_teams = final_teams.append(MI,ignore_index = True)
final_teams
# Out:
# <ipython-input-16-d3bb573ac257>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(MI,ignore_index = True)
#              Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0              Shivam Mavi    4000000        BOWLER              6.0
# 1            Joshua Little    5000000        BOWLER              4.4
# 2          Kane Williamson   20000000       BATSMAN              2.0
# 3              K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4             Mohit Sharma    5000000        BOWLER              0.5
# ..                     ...        ...           ...              ...
# 163          Dewald Brevis   Retained       BATSMAN              0.0
# 164           Ishan Kishan   Retained  WICKETKEEPER              0.0
# 165         Jasprit Bumrah   Retained        BOWLER              0.0
# ...

# %%
data[8]
# Out:
#          2023 Squad RCB Base Price          TYPE  COST IN ₹ (CR.)  \
# 0            Will Jacks    1500000       BATSMAN              3.2
# 1          Reece Topley    7500000        BOWLER              1.9
# 2           Rajan Kumar    2000000        BOWLER              0.7
# 3         Avinash Singh    2000000        BOWLER              0.6
# 4        Manoj Bhandage    2000000   ALL-ROUNDER              0.2
# 5            Sonu Yadav    2000000   ALL-ROUNDER              0.2
# 6       Himanshu Sharma    2000000        BOWLER              0.2
# 7         Rajat Patidar   Retained       BATSMAN              0.0
# 8        Mahipal Lomror   Retained        BOWLER              0.0
# 9        Shahbaz Ahamad   Retained   ALL-ROUNDER              0.0
# 10       Mohammed Siraj   Retained        BOWLER              0.0
# 11    Wanindu Hasaranga   Retained   ALL-ROUNDER              0.0
# 12          Karn Sharma   Retained        BOWLER              0.0
# ...

# %%
RCB = data[8]
RCB["Team"] = "Royal Challengers Banglore"
RCB.rename(columns={"2023 Squad RCB":"Player's List"},inplace = True)
final_teams = final_teams.append(RCB,ignore_index = True)
final_teams
# Out:
# <ipython-input-18-8573057fa19a>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(RCB,ignore_index = True)
#        Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0        Shivam Mavi    4000000        BOWLER              6.0
# 1      Joshua Little    5000000        BOWLER              4.4
# 2    Kane Williamson   20000000       BATSMAN              2.0
# 3        K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4       Mohit Sharma    5000000        BOWLER              0.5
# ..               ...        ...           ...              ...
# 188   Dinesh Karthik   Retained  WICKETKEEPER              0.0
# 189   Faf Du Plessis   Retained       BATSMAN              0.0
# 190    Harshal Patel   Retained   ALL-ROUNDER              0.0
# 191    Glenn Maxwell   Retained   ALL-ROUNDER              0.0
# ...

# %%
data[9]
# Out:
#        2023 Squad RR Base Price          TYPE  COST IN ₹ (CR.)  \
# 0       Jason Holder   20000000   ALL-ROUNDER             5.75
# 1         Adam Zampa    1500000        BOWLER             1.50
# 2           Joe Root   10000000       BATSMAN             1.00
# 3   Donovan Ferreira    2000000  WICKETKEEPER             0.50
# 4          K.M. Asif    3000000        BOWLER             0.30
# 5      Kunal Rathore    2000000  WICKETKEEPER             0.20
# 6          Abdul P A    2000000   ALL-ROUNDER             0.20
# 7     Akash Vashisht    2000000   ALL-ROUNDER             0.20
# 8     Murugan Ashwin    2000000        BOWLER             0.20
# 9       Sanju Samson   Retained  WICKETKEEPER             0.00
# 10       Riyan Parag   Retained   ALL-ROUNDER             0.00
# 11         R. Ashwin   Retained   ALL-ROUNDER             0.00
# 12   Shimron Hetmyer   Retained       BATSMAN             0.00
# 13       Trent Boult   Retained        BOWLER             0.00
# ...

# %%
RR = data[9]
RR["Team"] = "Rajasthan Royals"
RR.rename(columns={"2023 Squad RR":"Player's List"},inplace = True)
final_teams = final_teams.append(RR,ignore_index = True)
final_teams
# Out:
# <ipython-input-20-677b2c89cd4e>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(RR,ignore_index = True)
#        Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0        Shivam Mavi    4000000        BOWLER              6.0
# 1      Joshua Little    5000000        BOWLER              4.4
# 2    Kane Williamson   20000000       BATSMAN              2.0
# 3        K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4       Mohit Sharma    5000000        BOWLER              0.5
# ..               ...        ...           ...              ...
# 213      Jos Buttler   Retained  WICKETKEEPER              0.0
# 214      Kuldeep Sen   Retained        BOWLER              0.0
# 215    Navdeep Saini   Retained        BOWLER              0.0
# 216     Kuldip Yadav   Retained        BOWLER              0.0
# ...

# %%
data[10]
# Out:
#          2023 Squad SRH Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Harry Brook   15000000       BATSMAN            13.25
# 1        Mayank Agarwal   10000000       BATSMAN             8.25
# 2      Heinrich Klaasen   10000000  WICKETKEEPER             5.25
# 3        Vivrant Sharma    2000000   ALL-ROUNDER             2.60
# 4           Adil Rashid   20000000        BOWLER             2.00
# 5          Mayank Dagar    2000000   ALL-ROUNDER             1.80
# 6          Akeal Hosein   10000000        BOWLER             1.00
# 7       Mayank Markande    5000000        BOWLER             0.50
# 8   Upendra Singh Yadav    2000000  WICKETKEEPER             0.25
# 9    Nitish Kumar Reddy    2000000  WICKETKEEPER             0.20
# 10         Samarth Vyas    2000000   ALL-ROUNDER             0.20
# 11     Anmolpreet Singh    2000000       BATSMAN             0.20
# 12         Sanvir Singh    2000000   ALL-ROUNDER             0.20
# ...

# %%
SRH = data[10]
SRH["Team"] = "Sunrisers Hyderabad"
SRH.rename(columns={"2023 Squad SRH":"Player's List"},inplace = True)
final_teams = final_teams.append(SRH,ignore_index = True)
final_teams
# Out:
# <ipython-input-22-7184c02cfeac>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(SRH,ignore_index = True)
#          Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Shivam Mavi    4000000        BOWLER              6.0
# 1        Joshua Little    5000000        BOWLER              4.4
# 2      Kane Williamson   20000000       BATSMAN              2.0
# 3          K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4         Mohit Sharma    5000000        BOWLER              0.5
# ..                 ...        ...           ...              ...
# 238        Abdul Samad   Retained       BATSMAN              0.0
# 239    Abhishek Sharma   Retained   ALL-ROUNDER              0.0
# 240      Aiden Markram   Retained       BATSMAN              0.0
# 241  Bhuvneshwar Kumar   Retained        BOWLER              0.0
# ...

# %%
data[11]
# Out:
#                Players          TYPE  Base Price IN ₹  Base Price IN $  \
# 0           Tom Banton  WICKETKEEPER         20000000           240000
# 1         Kusal Mendis  WICKETKEEPER          5000000            60000
# 2         Chris Jordan        BOWLER         20000000           240000
# 3           Adam Milne        BOWLER         20000000           240000
# 4        Mujeeb Rahman        BOWLER         10000000           120000
# ..                 ...           ...              ...              ...
# 320        Dhruv Patel   ALL-ROUNDER          2000000            24000
# 321    Jack Prestwidge   ALL-ROUNDER          2000000            24000
# 322     Aditya Sarvate   ALL-ROUNDER          2000000            24000
# 323      Sagar Solanki   ALL-ROUNDER          2000000            24000
# 324  Prenelan Subrayen   ALL-ROUNDER          2000000            24000
#
#     2022 Squad
# 0          NaN
# 1          NaN
# 2          CSK
# 3          CSK
# 4          NaN
# ..         ...
# ...

# %%
unsold = data[11]
unsold.columns
# Out:
# Index(['Players', 'TYPE', 'Base Price IN ₹', 'Base Price IN $', '2022 Squad'], dtype='object')

# %%
unsold = data[11]
unsold.rename(columns = {"Players":"Player's List"},inplace = True)
unsold["Team"] = "Unsold"
unsold.rename(columns={"Base Price IN ₹":"Base Price"},inplace=True)
unsold.drop("Base Price IN $",axis=1,inplace=True)
unsold["COST IN ₹ (CR.)"]=np.nan
unsold["Cost IN $ (000)"]=np.nan
unsold
# Out:
#          Player's List          TYPE  Base Price 2022 Squad    Team  \
# 0           Tom Banton  WICKETKEEPER    20000000        NaN  Unsold
# 1         Kusal Mendis  WICKETKEEPER     5000000        NaN  Unsold
# 2         Chris Jordan        BOWLER    20000000        CSK  Unsold
# 3           Adam Milne        BOWLER    20000000        CSK  Unsold
# 4        Mujeeb Rahman        BOWLER    10000000        NaN  Unsold
# ..                 ...           ...         ...        ...     ...
# 320        Dhruv Patel   ALL-ROUNDER     2000000        NaN  Unsold
# 321    Jack Prestwidge   ALL-ROUNDER     2000000        NaN  Unsold
# 322     Aditya Sarvate   ALL-ROUNDER     2000000        NaN  Unsold
# 323      Sagar Solanki   ALL-ROUNDER     2000000        NaN  Unsold
# 324  Prenelan Subrayen   ALL-ROUNDER     2000000        NaN  Unsold
#
#      COST IN ₹ (CR.)  Cost IN $ (000)
# 0                NaN              NaN
# 1                NaN              NaN
# ...

# %%
unsold.columns
# Out:
# Index(['Player's List', 'TYPE', 'Base Price', '2022 Squad', 'Team',
#        'COST IN ₹ (CR.)', 'Cost IN $ (000)'],
#       dtype='object')

# %%
unsold = unsold[["Player's List",'Base Price', 'TYPE', 'COST IN ₹ (CR.)', 'Cost IN $ (000)','2022 Squad', 'Team']]
unsold
# Out:
#          Player's List  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Tom Banton    20000000  WICKETKEEPER              NaN
# 1         Kusal Mendis     5000000  WICKETKEEPER              NaN
# 2         Chris Jordan    20000000        BOWLER              NaN
# 3           Adam Milne    20000000        BOWLER              NaN
# 4        Mujeeb Rahman    10000000        BOWLER              NaN
# ..                 ...         ...           ...              ...
# 320        Dhruv Patel     2000000   ALL-ROUNDER              NaN
# 321    Jack Prestwidge     2000000   ALL-ROUNDER              NaN
# 322     Aditya Sarvate     2000000   ALL-ROUNDER              NaN
# 323      Sagar Solanki     2000000   ALL-ROUNDER              NaN
# 324  Prenelan Subrayen     2000000   ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2022 Squad    Team
# 0                NaN        NaN  Unsold
# 1                NaN        NaN  Unsold
# 2                NaN        CSK  Unsold
# ...

# %%
final_teams = final_teams.append(unsold,ignore_index = True)
final_teams
# Out:
# <ipython-input-28-c18e1aabb1f6>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_teams = final_teams.append(unsold,ignore_index = True)
#          Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Shivam Mavi    4000000        BOWLER              6.0
# 1        Joshua Little    5000000        BOWLER              4.4
# 2      Kane Williamson   20000000       BATSMAN              2.0
# 3          K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4         Mohit Sharma    5000000        BOWLER              0.5
# ..                 ...        ...           ...              ...
# 563        Dhruv Patel    2000000   ALL-ROUNDER              NaN
# 564    Jack Prestwidge    2000000   ALL-ROUNDER              NaN
# 565     Aditya Sarvate    2000000   ALL-ROUNDER              NaN
# 566      Sagar Solanki    2000000   ALL-ROUNDER              NaN
# ...

# %%
final_teams.to_csv("IPL_Squad_2023_Auction_Dataset.csv")

# %%
final_teams
# Out:
#          Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Shivam Mavi    4000000        BOWLER              6.0
# 1        Joshua Little    5000000        BOWLER              4.4
# 2      Kane Williamson   20000000       BATSMAN              2.0
# 3          K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4         Mohit Sharma    5000000        BOWLER              0.5
# ..                 ...        ...           ...              ...
# 563        Dhruv Patel    2000000   ALL-ROUNDER              NaN
# 564    Jack Prestwidge    2000000   ALL-ROUNDER              NaN
# 565     Aditya Sarvate    2000000   ALL-ROUNDER              NaN
# 566      Sagar Solanki    2000000   ALL-ROUNDER              NaN
# 567  Prenelan Subrayen    2000000   ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2022 Squad            Team
# 0              720.0        KKR  Gujarat Titans
# 1              528.0        NaN  Gujarat Titans
# ...
